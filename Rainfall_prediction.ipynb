# %% [markdown]
# <a href="https://colab.research.google.com/github/SimAdm12/MY-Certifications/blob/main/Rainfall_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv("austin_weather.csv")

# %%
dataset
# Out:
#             Date  TempHighF  TempAvgF  TempLowF DewPointHighF DewPointAvgF  \
# 0     2013-12-21         74        60        45            67           49
# 1     2013-12-22         56        48        39            43           36
# 2     2013-12-23         58        45        32            31           27
# 3     2013-12-24         61        46        31            36           28
# 4     2013-12-25         58        50        41            44           40
# ...          ...        ...       ...       ...           ...          ...
# 1314  2017-07-27        103        89        75            71           67
# 1315  2017-07-28        105        91        76            71           64
# 1316  2017-07-29        107        92        77            72           64
# 1317  2017-07-30        106        93        79            70           68
# 1318  2017-07-31         99        88        77            66           61
#
# ...

# %%
dataset = dataset.drop(["Events","Date","SeaLevelPressureLowInches"], axis=1 )

# %%
dataset
# Out:
#       TempHighF  TempAvgF  TempLowF DewPointHighF DewPointAvgF DewPointLowF  \
# 0            74        60        45            67           49           43
# 1            56        48        39            43           36           28
# 2            58        45        32            31           27           23
# 3            61        46        31            36           28           21
# 4            58        50        41            44           40           36
# ...         ...       ...       ...           ...          ...          ...
# 1314        103        89        75            71           67           61
# 1315        105        91        76            71           64           55
# 1316        107        92        77            72           64           55
# 1317        106        93        79            70           68           63
# 1318         99        88        77            66           61           54
#
# ...

# %%
dataset = dataset.replace('T',0.0)

# %%
dataset = dataset.replace('-',0.0)

# %%
dataset.to_csv("austin_weather_final.csv")

# %%
import pandas as pd
import numpy as np
import sklearn as sk
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv("austin_weather_final.csv")

# %%
dataset
# Out:
#       Unnamed: 0  TempHighF  TempAvgF  TempLowF  DewPointHighF  DewPointAvgF  \
# 0              0         74        60        45           67.0          49.0
# 1              1         56        48        39           43.0          36.0
# 2              2         58        45        32           31.0          27.0
# 3              3         61        46        31           36.0          28.0
# 4              4         58        50        41           44.0          40.0
# ...          ...        ...       ...       ...            ...           ...
# 1314        1314        103        89        75           71.0          67.0
# 1315        1315        105        91        76           71.0          64.0
# 1316        1316        107        92        77           72.0          64.0
# 1317        1317        106        93        79           70.0          68.0
# 1318        1318         99        88        77           66.0          61.0
#
# ...

# %%
x = dataset.drop(["PrecipitationSumInches"],axis=1)
y = dataset["PrecipitationSumInches"]

# %%
# reshaping it into 2D format
y=y.reshape(-1,1)
y
# Out:
# array([[0.46],
#        [0.  ],
#        [0.  ],
#        ...,
#        [0.  ],
#        [0.  ],
#        [0.  ]])

# %%
day_index  = 799
days = [i for i in range(y.size) ]
days

# %%
# initialize the linear regression classifier
clf =  LinearRegression()

# training the classifier
clf.fit(x,y)
# Out:
# LinearRegression()

# %%
# plot a graph
print("The percipitation trend graph")
plt.scatter( days , y, color= 'g')
plt.scatter(days[day_index], y[day_index], color = 'r')
plt.title("precipitation level")
plt.xlabel =("Days")
plt.ylabel =("percipitation in inches")
plt.show()
x_vis = x.filter(["TempAvgF","DewPointAvgF","HumidityAvgPercent","SeaLevelPressureAvgInches","VisibilityAvgMiles","WindAvgMPH"])
# Out:
# The percipitation trend graph

# %%
print ("The percipitation vs attributes trend graph ")

for i in range(x_vis.columns.size):
  plt.subplot(3, 2,i+1)
  plt.scatter(days ,x_vis[x_vis.columns.values[i][:100]], color ='g')
  plt.scatter(days[day_index], x_vis[x_vis.columns.values[i]][day_index],color='r')
  plt.title(x_vis.columns.values[i])
plt.show()
# Out:
# The percipitation vs attributes trend graph
